# %%
from sklearn import datasets, tree
import numpy as np
import pandas  as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
iris = datasets.load_iris()

# %%
x,y= iris.data[:, :2],  iris.target
x_train,x_test, y_train,y_test = train_test_split(x,y,test_size=0.3, random_state =0)

# %%
x = iris.data
y = iris.target

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler().fit(x)

# %%
model = tree.DecisionTreeClassifier(criterion = 'entropy', random_state = 0)

# %%
model.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=0)

# %%
#generating evaluation matrix

from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
print('TrainAccuracy:', accuracy_score(y_train, model.predict(x_train)))
print('TrainConfusionMatrix:',confusion_matrix(y_train,model.predict(x_train)))
# Out:
# TrainAccuracy: 0.9428571428571428
# TrainConfusionMatrix: [[34  0  0]
#  [ 0 32  0]
#  [ 0  6 33]]

# %%
print('TestAccuracy:', accuracy_score(y_test, model.predict(x_test)))
print('TestConfusionMatrix:',confusion_matrix(y_test,model.predict(x_test)))
print('TestClassificationReport:', classification_report(y_test,model.predict(x_test)))
# Out:
# TestAccuracy: 0.6444444444444445
# TestConfusionMatrix: [[16  0  0]
#  [ 1 10  7]
#  [ 0  8  3]]
# TestClassificationReport:               precision    recall  f1-score   support
#
#            0       0.94      1.00      0.97        16
#            1       0.56      0.56      0.56        18
#            2       0.30      0.27      0.29        11
#
#     accuracy                           0.64        45
#    macro avg       0.60      0.61      0.60        45
# weighted avg       0.63      0.64      0.64        45

# %%
sns.heatmap(classification_report(y_test,model.predict(x_test)), cmap ='RdBu_r', annot=True, fmt ='2f', vmin=-1, vmax=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[78], line 1
# ----> 1 sns.heatmap(classification_report(y_test,model.predict(x_test)), cmap ='RdBu_r', annot=True, fmt ='2f', vmin=-1, vmax=1)
#       2 plt.show()
#
# File ~\anaconda3\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
# ...

# %%
from sklearn.externals.six import StringIO
import pydot
out_data = StringID()
tree.export_gravpviz(clf, out_file  = out_data, feature_names = model.classes_.astype(int).astype(str),filled = True, rounded= True,
                     special_characters=True, node_id=1,)
graph = pydot.graph_fromdot_data(out_data.getvalue())
